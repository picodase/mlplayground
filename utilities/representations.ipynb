# %%
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage
smiles_list = ["CCCCC","CCOCC","CCNCC","CCSCC", "C=CC#CC=C"]
mol_list = [Chem.MolFromSmiles(x) for x in smiles_list] 
MolsToGridImage(mols=mol_list)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x400 at 0x7F2265E91E80>

# %%
query = Chem.MolFromSmarts("CC[O,C,S,N]")
match_list = [mol.GetSubstructMatch(query) for mol in
mol_list]
MolsToGridImage(mols=mol_list, molsPerRow=4,
highlightAtomLists=match_list)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x400 at 0x7F2265E913A0>

# %%
smiles_list = ["CC(C=O)C=CC","O=C(C=C)C(C=O)CC=O"]
mol_list = [Chem.MolFromSmiles(x) for x in smiles_list] 
MolsToGridImage(mols=mol_list)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x200 at 0x7F2265E914F0>

# %%
import nglview as nglv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-acae5c048517> in <module>
# ----> 1 import nglview as nglv
#
# ModuleNotFoundError: No module named 'nglview'

# %%
view = nglv.show_pdbid("2d3u")  # load "3pqr" from RCSB PDB and display viewer widget
view
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6cf1a4665381> in <module>
# ----> 1 view = nglv.show_pdbid("2d3u")  # load "3pqr" from RCSB PDB and display viewer widget
#       2 view
#
# NameError: name 'nglv' is not defined
